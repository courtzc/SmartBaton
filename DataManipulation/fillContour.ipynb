# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os 
cwd = os.getcwd()

print(cwd)

source_of_truth = cv2.imread("..\\Visualisations\\Session01_Resampled_Average_Figures\\plain_average_for_analysis.png") #raw RGB image
# print(source_of_truth)
im2 = cv2.cvtColor(source_of_truth,cv2.COLOR_BGR2GRAY) #gray scale image
source_of_truth_gray = cv2.cvtColor(source_of_truth, cv2.COLOR_BGR2GRAY)
plt.imshow(im2,cmap = 'gray')
plt.show()
# Out:
# c:\Users\Courtney\source\repos\ThesisProject\DataManipulation

# %%
ret, thresh = cv2.threshold(source_of_truth_gray, 127, 255, 0)
im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

im3 = cv2.drawContours(im2, contours, -1, (0,255,0), 3)
plt.imshow(im3,cmap = 'gray')
plt.show()
